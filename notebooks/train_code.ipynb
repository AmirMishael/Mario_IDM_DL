# %%
# !git clone https://github.com/AmirMishael/Mario_IDM_DL.git ./tmp_git
# !cp -r ./tmp_git/* ./
# !rm -rf ./tmp_git
# !chmod 777 ./download_data.bash
# !./download_data.bash
# Out:
# Cloning into './tmp_git'...
# remote: Enumerating objects: 206, done.
# remote: Counting objects: 100% (206/206), done.
# remote: Compressing objects: 100% (135/135), done.
# remote: Total 206 (delta 111), reused 127 (delta 49), pack-reused 0
# Receiving objects: 100% (206/206), 185.13 KiB | 2.54 MiB/s, done.
# Resolving deltas: 100% (111/111), done.
# /bin/bash: ./download_data.bash: /bin/bash^M: bad interpreter: No such file or directory

# %%
# !mkdir "./tmp_download"
# !wget "https://github.com/rafaelcp/smbdataset/raw/main/data-smb.7z" -O "./tmp_download/data-smb.7z"
!7za x "./tmp_download/data-smb.7z" -o./mario_dataset -y -mmt=8
# !rm -rf "./tmp_download"
# Out:
# --2023-06-09 10:15:30--  https://github.com/rafaelcp/smbdataset/raw/main/data-smb.7z
# Resolving github.com (github.com)... 140.82.112.4
# Connecting to github.com (github.com)|140.82.112.4|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://media.githubusercontent.com/media/rafaelcp/smbdataset/main/data-smb.7z [following]
# --2023-06-09 10:15:31--  https://media.githubusercontent.com/media/rafaelcp/smbdataset/main/data-smb.7z
# Resolving media.githubusercontent.com (media.githubusercontent.com)... 185.199.110.133, 185.199.109.133, 185.199.111.133, ...
# Connecting to media.githubusercontent.com (media.githubusercontent.com)|185.199.110.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 932651968 (889M) [application/octet-stream]
# Saving to: ‘./tmp_download/data-smb.7z’
#
# ./tmp_download/data 100%[===================>] 889.45M   185MB/s    in 7.3s
#
# 2023-06-09 10:15:49 (121 MB/s) - ‘./tmp_download/data-smb.7z’ saved [932651968/932651968]
#
#
# 7-Zip (a) [64] 16.02 : Copyright (c) 1999-2016 Igor Pavlov : 2016-05-21
# p7zip Version 16.02 (locale=en_US.UTF-8,Utf16=on,HugeFiles=on,64 bits,2 CPUs Intel(R) Xeon(R) CPU @ 2.30GHz (306F0),ASM,AES-NI)
#
# Scanning the drive for archives:
# 1 file, 932651968 bytes (890 MiB)
#
# Extracting archive: ./tmp_download/data-smb.7z
# --
# Path = ./tmp_download/data-smb.7z
# Type = 7z
# Physical Size = 932651968
# Headers Size = 6735576
# Method = LZMA2:24
# Solid = +
# Blocks = 3
#
# Everything is Ok
#
# Folders: 280
# Files: 737134
# Size:       3470098827
# Compressed: 932651968

# %%
from google.colab import drive

drive.mount("/content/gdrive")

modles_path = "./gdrive/MyDrive/models"
# Out:
# Mounted at /content/gdrive

# %% [markdown]
# # Train

# %%
import torch
import torchvision
import os
from torch.utils.data import Dataset
from PIL import Image
from tqdm import tqdm
import pathlib
from helper_code.train import main_train

main_train(models_dir=modles_path)
# Out:
# cuda:0
# loading dataset preload:False
# total episodes:188
# total episodes:53
# total episodes:39
# tot train dataset frames :501037
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:560: UserWarning: This DataLoader will create 8 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# Downloading: "https://github.com/pytorch/vision/zipball/v0.6.0" to /root/.cache/torch/hub/v0.6.0.zip
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet18_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet18_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Downloading: "https://download.pytorch.org/models/resnet18-f37072fd.pth" to /root/.cache/torch/hub/checkpoints/resnet18-f37072fd.pth
# 100%|██████████| 44.7M/44.7M [00:00<00:00, 205MB/s]
# started training with hyperparams: group:3, epochs:7, learning_rate:0.001
# training epoch:1:   0%|          | 0/3915 [00:00<?, ?it/s]
# saving checkpoint at epoch:1, batch:0, loss:0.7394853830337524
# training epoch:1:  13%|█▎        | 500/3915 [05:57<34:29,  1.65it/s]
# saving checkpoint at epoch:1, batch:500, loss:0.19581705331802368
# training epoch:1:  26%|██▌       | 1000/3915 [11:40<39:36,  1.23it/s]
# saving checkpoint at epoch:1, batch:1000, loss:0.14401951432228088
# training epoch:1:  38%|███▊      | 1500/3915 [17:23<26:53,  1.50it/s]
# saving checkpoint at epoch:1, batch:1500, loss:0.14678668975830078
# training epoch:1:  51%|█████     | 2000/3915 [23:06<19:39,  1.62it/s]
# saving checkpoint at epoch:1, batch:2000, loss:0.17280471324920654
# training epoch:1:  64%|██████▍   | 2500/3915 [28:47<13:42,  1.72it/s]
# saving checkpoint at epoch:1, batch:2500, loss:0.09348940849304199
# training epoch:1:  77%|███████▋  | 3000/3915 [34:33<12:08,  1.26it/s]
# saving checkpoint at epoch:1, batch:3000, loss:0.1404980570077896
# training epoch:1:  89%|████████▉ | 3500/3915 [40:16<04:17,  1.61it/s]
# saving checkpoint at epoch:1, batch:3500, loss:0.1006745845079422
# training epoch:1: 100%|██████████| 3915/3915 [44:58<00:00,  1.45it/s]
# calculating accuracy
# calculating accuracy: 100%|██████████| 721/721 [07:10<00:00,  1.68it/s]
# accuracy: 0.8802113264011624
# running loss : 0.1367803507419077 , epoch:1
# training epoch:2:   0%|          | 0/3915 [00:00<?, ?it/s]
# saving checkpoint at epoch:2, batch:0, loss:0.09455731511116028
# training epoch:2:  13%|█▎        | 500/3915 [05:54<37:53,  1.50it/s]
# saving checkpoint at epoch:2, batch:500, loss:0.06617565453052521
# training epoch:2:  26%|██▌       | 1000/3915 [11:36<28:56,  1.68it/s]
# saving checkpoint at epoch:2, batch:1000, loss:0.07599148154258728
# training epoch:2:  38%|███▊      | 1500/3915 [17:22<33:37,  1.20it/s]
# saving checkpoint at epoch:2, batch:1500, loss:0.10483080893754959
# training epoch:2:  51%|█████     | 2000/3915 [23:06<19:58,  1.60it/s]
# saving checkpoint at epoch:2, batch:2000, loss:0.08081546425819397
# training epoch:2:  64%|██████▍   | 2500/3915 [28:50<16:29,  1.43it/s]
# saving checkpoint at epoch:2, batch:2500, loss:0.049381181597709656
# training epoch:2:  77%|███████▋  | 3000/3915 [34:35<10:23,  1.47it/s]
# saving checkpoint at epoch:2, batch:3000, loss:0.052394941449165344
# training epoch:2:  89%|████████▉ | 3500/3915 [40:19<04:10,  1.66it/s]
# saving checkpoint at epoch:2, batch:3500, loss:0.07572709023952484
# training epoch:2: 100%|██████████| 3915/3915 [45:04<00:00,  1.45it/s]
# calculating accuracy
# calculating accuracy: 100%|██████████| 721/721 [07:13<00:00,  1.66it/s]
# accuracy: 0.8829220293406486
# running loss : 0.07805344432706578 , epoch:2
# training epoch:3:   0%|          | 0/3915 [00:00<?, ?it/s]
# saving checkpoint at epoch:3, batch:0, loss:0.05239685997366905
# training epoch:3:  13%|█▎        | 500/3915 [05:52<36:25,  1.56it/s]
# saving checkpoint at epoch:3, batch:500, loss:0.06716413795948029
# training epoch:3:  26%|██▌       | 1000/3915 [11:36<34:06,  1.42it/s]
# saving checkpoint at epoch:3, batch:1000, loss:0.040844254195690155
# training epoch:3:  38%|███▊      | 1500/3915 [17:24<25:16,  1.59it/s]
# saving checkpoint at epoch:3, batch:1500, loss:0.06600889563560486
# training epoch:3:  51%|█████     | 2000/3915 [23:11<24:14,  1.32it/s]
# saving checkpoint at epoch:3, batch:2000, loss:0.04763704910874367
# training epoch:3:  64%|██████▍   | 2500/3915 [29:00<14:31,  1.62it/s]
# saving checkpoint at epoch:3, batch:2500, loss:0.04438963532447815
# training epoch:3:  77%|███████▋  | 3000/3915 [34:50<11:38,  1.31it/s]
# saving checkpoint at epoch:3, batch:3000, loss:0.048530083149671555
# training epoch:3:  89%|████████▉ | 3500/3915 [40:36<04:17,  1.61it/s]
# saving checkpoint at epoch:3, batch:3500, loss:0.042047224938869476
# training epoch:3: 100%|██████████| 3915/3915 [45:21<00:00,  1.44it/s]
# calculating accuracy
# calculating accuracy: 100%|██████████| 721/721 [07:08<00:00,  1.68it/s]
# accuracy: 0.8886199269194488
# running loss : 0.05803586097902798 , epoch:3
# training epoch:4:   0%|          | 0/3915 [00:00<?, ?it/s]
# saving checkpoint at epoch:4, batch:0, loss:0.05595908313989639
# training epoch:4:  13%|█▎        | 500/3915 [05:49<35:01,  1.62it/s]
# saving checkpoint at epoch:4, batch:500, loss:0.03410451114177704
# training epoch:4:  26%|██▌       | 1000/3915 [11:30<29:00,  1.67it/s]
# saving checkpoint at epoch:4, batch:1000, loss:0.04083362966775894
# training epoch:4:  38%|███▊      | 1500/3915 [17:12<28:37,  1.41it/s]
# saving checkpoint at epoch:4, batch:1500, loss:0.046936772763729095
# training epoch:4:  51%|█████     | 2000/3915 [22:57<23:01,  1.39it/s]
# saving checkpoint at epoch:4, batch:2000, loss:0.0471007376909256
# training epoch:4:  64%|██████▍   | 2500/3915 [28:42<14:57,  1.58it/s]
# saving checkpoint at epoch:4, batch:2500, loss:0.06483076512813568
# training epoch:4:  77%|███████▋  | 3000/3915 [34:27<12:46,  1.19it/s]
# saving checkpoint at epoch:4, batch:3000, loss:0.04565296322107315
# training epoch:4:  84%|████████▎ | 3276/3915 [37:36<07:00,  1.52it/s]
