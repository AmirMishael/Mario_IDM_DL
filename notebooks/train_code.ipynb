# %%
# !git clone https://github.com/AmirMishael/Mario_IDM_DL.git ./tmp_git
# !cp -r ./tmp_git/* ./
# !rm -rf ./tmp_git
# !chmod 777 ./download_data.bash
# !./download_data.bash
# Out:
# Cloning into './tmp_git'...
# remote: Enumerating objects: 85, done.
# remote: Counting objects: 100% (85/85), done.
# remote: Compressing objects: 100% (53/53), done.
# remote: Total 85 (delta 34), reused 54 (delta 18), pack-reused 0
# Unpacking objects: 100% (85/85), 91.53 KiB | 1.24 MiB/s, done.
# --2023-06-03 12:39:19--  https://github.com/rafaelcp/smbdataset/raw/main/data-smb.7z
# Resolving github.com (github.com)... 192.30.255.112
# Connecting to github.com (github.com)|192.30.255.112|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://media.githubusercontent.com/media/rafaelcp/smbdataset/main/data-smb.7z [following]
# --2023-06-03 12:39:19--  https://media.githubusercontent.com/media/rafaelcp/smbdataset/main/data-smb.7z
# Resolving media.githubusercontent.com (media.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to media.githubusercontent.com (media.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 932651968 (889M) [application/octet-stream]
# Saving to: ‘./tmp_download/data-smb.7z’
#
# ./tmp_download/data 100%[===================>] 889.45M   187MB/s    in 7.4s
#
# 2023-06-03 12:39:48 (120 MB/s) - ‘./tmp_download/data-smb.7z’ saved [932651968/932651968]
#
#
# 7-Zip (a) [64] 16.02 : Copyright (c) 1999-2016 Igor Pavlov : 2016-05-21
# p7zip Version 16.02 (locale=en_US.UTF-8,Utf16=on,HugeFiles=on,64 bits,2 CPUs Intel(R) Xeon(R) CPU @ 2.20GHz (406F0),ASM,AES-NI)
#
# Scanning the drive for archives:
# 1 file, 932651968 bytes (890 MiB)
#
# Extracting archive: ./tmp_download/data-smb.7z
# --
# Path = ./tmp_download/data-smb.7z
# Type = 7z
# Physical Size = 932651968
# Headers Size = 6735576
# Method = LZMA2:24
# Solid = +
# Blocks = 3
#
# Everything is Ok
#
# Folders: 280
# Files: 737134
# Size:       3470098827
# Compressed: 932651968

# %%
from google.colab import drive

drive.mount("/content/gdrive")

modles_path = "./gdrive/MyDrive/models"
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %% [markdown]
# # Train

# %%
import torch
import torchvision
import os
from torch.utils.data import Dataset
from PIL import Image
from tqdm import tqdm
import pathlib
from helper_code.train import main_train

main_train(models_dir=modles_path)
# Out:
# cuda:0
# total episodes:280
# tot dataset frames :736574
# Using cache found in /root/.cache/torch/hub/pytorch_vision_v0.6.0
# started training with hyperparams: group:3, epochs:7, learning_rate:0.0001
#   0%|          | 1/4029 [00:00<1:02:42,  1.07it/s]
# saving checkpoint at epoch:1, batch:0
#   5%|▍         | 201/4029 [03:10<1:09:05,  1.08s/it]
# saving checkpoint at epoch:1, batch:200
#  10%|▉         | 401/4029 [06:08<52:39,  1.15it/s]
# saving checkpoint at epoch:1, batch:400
#  15%|█▍        | 601/4029 [09:07<59:53,  1.05s/it]
# saving checkpoint at epoch:1, batch:600
#  20%|█▉        | 801/4029 [12:10<46:40,  1.15it/s]
# saving checkpoint at epoch:1, batch:800
#  25%|██▍       | 1001/4029 [15:09<54:34,  1.08s/it]
# saving checkpoint at epoch:1, batch:1000
#  30%|██▉       | 1201/4029 [18:13<45:41,  1.03it/s]
# saving checkpoint at epoch:1, batch:1200
#  35%|███▍      | 1401/4029 [21:14<40:53,  1.07it/s]
# saving checkpoint at epoch:1, batch:1400
#  40%|███▉      | 1601/4029 [24:20<44:10,  1.09s/it]
# saving checkpoint at epoch:1, batch:1600
#  45%|████▍     | 1801/4029 [27:22<32:22,  1.15it/s]
# saving checkpoint at epoch:1, batch:1800
#  50%|████▉     | 2001/4029 [30:23<34:16,  1.01s/it]
# saving checkpoint at epoch:1, batch:2000
#  55%|█████▍    | 2201/4029 [33:25<26:20,  1.16it/s]
# saving checkpoint at epoch:1, batch:2200
#  60%|█████▉    | 2401/4029 [36:28<25:41,  1.06it/s]
# saving checkpoint at epoch:1, batch:2400
#  65%|██████▍   | 2601/4029 [39:28<20:48,  1.14it/s]
# saving checkpoint at epoch:1, batch:2600
#  70%|██████▉   | 2801/4029 [42:33<18:38,  1.10it/s]
# saving checkpoint at epoch:1, batch:2800
#  74%|███████▍  | 3001/4029 [45:32<15:31,  1.10it/s]
# saving checkpoint at epoch:1, batch:3000
#  79%|███████▉  | 3201/4029 [48:33<12:25,  1.11it/s]
# saving checkpoint at epoch:1, batch:3200
#  84%|████████▍ | 3401/4029 [51:36<10:52,  1.04s/it]
# saving checkpoint at epoch:1, batch:3400
#  89%|████████▉ | 3601/4029 [54:34<06:24,  1.11it/s]
# saving checkpoint at epoch:1, batch:3600
#  94%|█████████▍| 3801/4029 [57:35<03:50,  1.01s/it]
# saving checkpoint at epoch:1, batch:3800
#  99%|█████████▉| 4001/4029 [1:00:37<00:25,  1.10it/s]
# saving checkpoint at epoch:1, batch:4000
# 100%|██████████| 4029/4029 [1:01:02<00:00,  1.10it/s]
#   0%|          | 1/4029 [00:01<1:22:08,  1.22s/it]
# saving checkpoint at epoch:2, batch:0
#   5%|▍         | 201/4029 [02:55<1:06:57,  1.05s/it]
# saving checkpoint at epoch:2, batch:200
#  10%|▉         | 401/4029 [05:54<55:30,  1.09it/s]
# saving checkpoint at epoch:2, batch:400
#  15%|█▍        | 601/4029 [08:51<46:10,  1.24it/s]
# saving checkpoint at epoch:2, batch:600
#  20%|█▉        | 801/4029 [11:49<55:28,  1.03s/it]
# saving checkpoint at epoch:2, batch:800
#  25%|██▍       | 1001/4029 [14:48<44:11,  1.14it/s]
# saving checkpoint at epoch:2, batch:1000
#  30%|██▉       | 1201/4029 [17:45<39:37,  1.19it/s]
# saving checkpoint at epoch:2, batch:1200
#  35%|███▍      | 1401/4029 [20:41<40:27,  1.08it/s]
# saving checkpoint at epoch:2, batch:1400
#  40%|███▉      | 1601/4029 [23:39<41:41,  1.03s/it]
# saving checkpoint at epoch:2, batch:1600
#  45%|████▍     | 1801/4029 [26:36<32:47,  1.13it/s]
# saving checkpoint at epoch:2, batch:1800
#  50%|████▉     | 2001/4029 [29:31<27:54,  1.21it/s]
# saving checkpoint at epoch:2, batch:2000
#  55%|█████▍    | 2201/4029 [32:26<25:29,  1.20it/s]
# saving checkpoint at epoch:2, batch:2200
#  60%|█████▉    | 2401/4029 [35:21<24:39,  1.10it/s]
# saving checkpoint at epoch:2, batch:2400
#  65%|██████▍   | 2601/4029 [38:20<24:05,  1.01s/it]
# saving checkpoint at epoch:2, batch:2600
#  70%|██████▉   | 2801/4029 [41:17<17:47,  1.15it/s]
# saving checkpoint at epoch:2, batch:2800
#  74%|███████▍  | 3001/4029 [44:13<14:47,  1.16it/s]
# saving checkpoint at epoch:2, batch:3000
#  79%|███████▉  | 3201/4029 [47:10<14:08,  1.02s/it]
# saving checkpoint at epoch:2, batch:3200
#  84%|████████▍ | 3401/4029 [50:08<09:49,  1.07it/s]
# saving checkpoint at epoch:2, batch:3400
#  89%|████████▉ | 3601/4029 [53:06<06:14,  1.14it/s]
# saving checkpoint at epoch:2, batch:3600
#  94%|█████████▍| 3801/4029 [56:03<03:17,  1.15it/s]
# saving checkpoint at epoch:2, batch:3800
#  99%|█████████▉| 4001/4029 [59:00<00:29,  1.05s/it]
# saving checkpoint at epoch:2, batch:4000
# 100%|██████████| 4029/4029 [59:24<00:00,  1.13it/s]
#   0%|          | 1/4029 [00:00<1:03:03,  1.06it/s]
# saving checkpoint at epoch:3, batch:0
#   5%|▍         | 201/4029 [02:54<53:32,  1.19it/s]
# saving checkpoint at epoch:3, batch:200
#  10%|▉         | 401/4029 [05:50<59:48,  1.01it/s]
# saving checkpoint at epoch:3, batch:400
#  15%|█▍        | 601/4029 [08:47<58:09,  1.02s/it]
# saving checkpoint at epoch:3, batch:600
#  20%|█▉        | 801/4029 [11:41<52:57,  1.02it/s]
# saving checkpoint at epoch:3, batch:800
#  25%|██▍       | 1001/4029 [14:35<45:42,  1.10it/s]
# saving checkpoint at epoch:3, batch:1000
#  30%|██▉       | 1201/4029 [17:30<40:51,  1.15it/s]
# saving checkpoint at epoch:3, batch:1200
#  35%|███▍      | 1401/4029 [20:24<37:38,  1.16it/s]
# saving checkpoint at epoch:3, batch:1400
#  40%|███▉      | 1601/4029 [23:23<39:40,  1.02it/s]
# saving checkpoint at epoch:3, batch:1600
#  45%|████▍     | 1801/4029 [26:21<36:53,  1.01it/s]
# saving checkpoint at epoch:3, batch:1800
#  50%|████▉     | 2001/4029 [29:20<29:32,  1.14it/s]
# saving checkpoint at epoch:3, batch:2000
#  55%|█████▍    | 2201/4029 [32:17<25:58,  1.17it/s]
# saving checkpoint at epoch:3, batch:2200
#  60%|█████▉    | 2401/4029 [35:16<28:12,  1.04s/it]
# saving checkpoint at epoch:3, batch:2400
#  65%|██████▍   | 2601/4029 [38:11<23:20,  1.02it/s]
# saving checkpoint at epoch:3, batch:2600
#  70%|██████▉   | 2801/4029 [41:06<18:05,  1.13it/s]
# saving checkpoint at epoch:3, batch:2800
#  74%|███████▍  | 3001/4029 [44:04<15:10,  1.13it/s]
# saving checkpoint at epoch:3, batch:3000
#  79%|███████▉  | 3201/4029 [47:00<11:52,  1.16it/s]
# saving checkpoint at epoch:3, batch:3200
#  84%|████████▍ | 3401/4029 [50:01<11:04,  1.06s/it]
# saving checkpoint at epoch:3, batch:3400
#  89%|████████▉ | 3601/4029 [53:00<06:08,  1.16it/s]
# saving checkpoint at epoch:3, batch:3600
#  94%|█████████▍| 3801/4029 [55:57<03:12,  1.19it/s]
# saving checkpoint at epoch:3, batch:3800
#  99%|█████████▉| 4001/4029 [58:55<00:29,  1.07s/it]
# saving checkpoint at epoch:3, batch:4000
# 100%|██████████| 4029/4029 [59:18<00:00,  1.13it/s]
#   0%|          | 1/4029 [00:00<1:06:46,  1.01it/s]
# saving checkpoint at epoch:4, batch:0
#   5%|▍         | 201/4029 [02:53<55:22,  1.15it/s]
# saving checkpoint at epoch:4, batch:200
#  10%|▉         | 401/4029 [05:47<52:42,  1.15it/s]
# saving checkpoint at epoch:4, batch:400
#  15%|█▍        | 601/4029 [08:43<49:11,  1.16it/s]
# saving checkpoint at epoch:4, batch:600
#  20%|█▉        | 801/4029 [11:43<57:26,  1.07s/it]
# saving checkpoint at epoch:4, batch:800
#  25%|██▍       | 1001/4029 [14:46<46:04,  1.10it/s]
# saving checkpoint at epoch:4, batch:1000
#  30%|██▉       | 1201/4029 [17:48<39:59,  1.18it/s]
# saving checkpoint at epoch:4, batch:1200
#  35%|███▍      | 1401/4029 [20:51<45:29,  1.04s/it]
# saving checkpoint at epoch:4, batch:1400
#  40%|███▉      | 1601/4029 [23:48<39:20,  1.03it/s]
# saving checkpoint at epoch:4, batch:1600
#  45%|████▍     | 1801/4029 [26:45<31:43,  1.17it/s]
# saving checkpoint at epoch:4, batch:1800
#  50%|████▉     | 2001/4029 [29:43<28:35,  1.18it/s]
# saving checkpoint at epoch:4, batch:2000
#  55%|█████▍    | 2201/4029 [32:41<30:24,  1.00it/s]
# saving checkpoint at epoch:4, batch:2200
#  60%|█████▉    | 2401/4029 [35:38<28:52,  1.06s/it]
# saving checkpoint at epoch:4, batch:2400
#  65%|██████▍   | 2601/4029 [38:35<21:20,  1.12it/s]
# saving checkpoint at epoch:4, batch:2600
#  70%|██████▉   | 2801/4029 [41:29<17:45,  1.15it/s]
# saving checkpoint at epoch:4, batch:2800
#  74%|███████▍  | 3001/4029 [44:25<14:06,  1.21it/s]
# saving checkpoint at epoch:4, batch:3000
#  79%|███████▉  | 3201/4029 [47:21<11:57,  1.15it/s]
# saving checkpoint at epoch:4, batch:3200
#  84%|████████▍ | 3401/4029 [50:21<10:59,  1.05s/it]
# saving checkpoint at epoch:4, batch:3400
#  89%|████████▉ | 3601/4029 [53:18<06:26,  1.11it/s]
# saving checkpoint at epoch:4, batch:3600
#  94%|█████████▍| 3801/4029 [56:15<03:18,  1.15it/s]
# saving checkpoint at epoch:4, batch:3800
#  99%|█████████▉| 4001/4029 [59:11<00:23,  1.17it/s]
# saving checkpoint at epoch:4, batch:4000
# 100%|██████████| 4029/4029 [59:36<00:00,  1.13it/s]
#   0%|          | 1/4029 [00:00<1:05:12,  1.03it/s]
# saving checkpoint at epoch:5, batch:0
#   5%|▍         | 201/4029 [02:51<1:02:45,  1.02it/s]
# saving checkpoint at epoch:5, batch:200
#  10%|▉         | 401/4029 [05:41<59:03,  1.02it/s]
# saving checkpoint at epoch:5, batch:400
#  15%|█▍        | 601/4029 [08:33<55:26,  1.03it/s]
# saving checkpoint at epoch:5, batch:600
#  20%|█▉        | 801/4029 [11:26<53:10,  1.01it/s]
# saving checkpoint at epoch:5, batch:800
#  25%|██▍       | 1001/4029 [14:23<51:52,  1.03s/it]
# saving checkpoint at epoch:5, batch:1000
#  30%|██▉       | 1201/4029 [17:19<41:27,  1.14it/s]
# saving checkpoint at epoch:5, batch:1200
#  35%|███▍      | 1401/4029 [20:13<36:59,  1.18it/s]
# saving checkpoint at epoch:5, batch:1400
#  40%|███▉      | 1601/4029 [23:08<34:26,  1.18it/s]
# saving checkpoint at epoch:5, batch:1600
#  45%|████▍     | 1801/4029 [26:01<31:06,  1.19it/s]
# saving checkpoint at epoch:5, batch:1800
#  50%|████▉     | 2001/4029 [28:59<35:01,  1.04s/it]
# saving checkpoint at epoch:5, batch:2000
#  55%|█████▍    | 2201/4029 [31:55<28:47,  1.06it/s]
# saving checkpoint at epoch:5, batch:2200
#  60%|█████▉    | 2401/4029 [34:49<23:08,  1.17it/s]
# saving checkpoint at epoch:5, batch:2400
#  65%|██████▍   | 2601/4029 [37:43<20:21,  1.17it/s]
# saving checkpoint at epoch:5, batch:2600
#  70%|██████▉   | 2801/4029 [40:38<16:50,  1.22it/s]
# saving checkpoint at epoch:5, batch:2800
#  74%|███████▍  | 3001/4029 [43:33<15:05,  1.13it/s]
# saving checkpoint at epoch:5, batch:3000
#  75%|███████▍  | 3017/4029 [43:47<13:47,  1.22it/s]
